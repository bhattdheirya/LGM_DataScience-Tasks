# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattdheirya/LGM_DataScience-Tasks/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Let's Grow More Begineer Level 1 - Task 4**

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Important Libraries**

# %%
import cv2
print(cv2.__version__)
import matplotlib.pyplot as plt
# Out:
# 4.1.2

# %%
img_path = r"/content/drive/MyDrive/meadow.jpeg"

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis('off')
plt.title('original image')
plt.show()

# %% [markdown]
# **Converting image to Gray Image**

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,6))
plt.imshow(gray_image,cmap='gray')
plt.axis('off')
plt.title('Gray image')
plt.show()

# %%
image_invert = cv2.bitwise_not(gray_image)
plt.figure(figsize=(8,6))
plt.imshow(image_invert,cmap='gray')
plt.axis('off')
plt.title('inverted Image')
plt.show()

# %% [markdown]
# **Converting image to blur**

# %%
Gsn_image = cv2.GaussianBlur(image_invert,(21,21),sigmaX=0,sigmaY=0)
plt.figure(figsize=(8,6))
plt.imshow(Gsn_image,cmap='gray')
plt.axis('off')
plt.title('Gaussian Blur Image')
plt.show()

# %% [markdown]
# **Converting timage to Pencil Sketch**

# %%
pencil_sketch = cv2.divide(gray_image,255 - Gsn_image, scale = 255)
plt.figure(figsize=(10,8))
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil_Sketch Image')
plt.show()
